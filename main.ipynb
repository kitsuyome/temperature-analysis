# %% [markdown]
# ## Анализ температурных данных и мониторинг текущей температуры через OpenWeatherMap API
#
# **Описание задания:**
# Вы аналитик в компании, занимающейся изучением климатических изменений и мониторингом температур в разных городах. Вам нужно провести анализ исторических данных о температуре для выявления сезонных закономерностей и аномалий. Также необходимо подключить API OpenWeatherMap для получения текущей температуры в выбранных городах и сравнить её с историческими данными.
#
#
# ### Цели задания:
# 1. Провести **анализ временных рядов**, включая:
#    - Вычисление скользящего среднего и стандартного отклонения для сглаживания температурных колебаний.
#    - Определение аномалий на основе отклонений температуры от $ \text{скользящее среднее} \pm 2\sigma $.
#    - Построение долгосрочных трендов изменения температуры.
#    - Любые дополнительные исследования будут вам в плюс.
#
# 2. Осуществить **мониторинг текущей температуры**:
#    - Получить текущую температуру через OpenWeatherMap API.
#    - Сравнить её с историческим нормальным диапазоном для текущего сезона.
#
# 3. Разработать **интерактивное приложение**:
#    - Дать пользователю возможность выбрать город.
#    - Отобразить результаты анализа температур, включая временные ряды, сезонные профили и аномалии.
#    - Провести анализ текущей температуры в контексте исторических данных.
#
#
# ### Описание данных
# Исторические данные о температуре содержатся в файле `temperature_data.csv`, включают:
#   - `city`: Название города.
#   - `timestamp`: Дата (с шагом в 1 день).
#   - `temperature`: Среднесуточная температура (в °C).
#   - `season`: Сезон года (зима, весна, лето, осень).
#
# Код для генерации файла вы найдете ниже.
#
# ### Этапы выполнения
#
# 1. **Анализ исторических данных**:
#    - Вычислить **скользящее среднее** температуры с окном в 30 дней для сглаживания краткосрочных колебаний.
#    - Рассчитать среднюю температуру и стандартное отклонение для каждого сезона в каждом городе.
#    - Выявить аномалии, где температура выходит за пределы $ \text{среднее} \pm 2\sigma $.
#    - Попробуйте распараллелить проведение этого анализа. Сравните скорость выполнения анализа с распараллеливанием и без него.
#
# 2. **Мониторинг текущей температуры**:
#    - Подключить OpenWeatherMap API для получения текущей температуры города. Для получения API Key (бесплатно) надо зарегистрироваться на сайте. Обратите внимание, что API Key может активироваться только через 2-3 часа, это нормально. Посему получите ключ заранее.
#    - Получить текущую температуру для выбранного города через OpenWeatherMap API.
#    - Определить, является ли текущая температура нормальной, исходя из исторических данных для текущего сезона.
#    - Данные на самом деле не совсем реальные (сюрпрайз). Поэтому на момент эксперимента погода в Берлине, Каире и Дубае была в рамках нормы, а в Пекине и Москве аномальная. Протестируйте свое решение для разных городов.
#    - Попробуйте для получения текущей температуры использовать синхронные и асинхронные методы. Что здесь лучше использовать?
#
# 3. **Создание приложения на Streamlit**:
#    - Добавить интерфейс для загрузки файла с историческими данными.
#    - Добавить интерфейс для выбора города (из выпадающего списка).
#    - Добавить форму для ввода API-ключа OpenWeatherMap. Когда он не введен, данные для текущей погоды не показываются. Если ключ некорректный, выведите на экран ошибку (должно приходить `{"cod":401, "message": "Invalid API key. Please see https://openweathermap.org/faq#error401 for more info."}`).
#    - Отобразить:
#      - Описательную статистику по историческим данным для города, можно добавить визуализации.
#      - Временной ряд температур с выделением аномалий (например, точками другого цвета).
#      - Сезонные профили с указанием среднего и стандартного отклонения.
#    - Вывести текущую температуру через API и указать, нормальна ли она для сезона.

# %% [markdown]
# ## Генерация данных

# %%
import pandas as pd
import numpy as np

from scripts import current_temp, analysis, async_current_temp
from utils import test_sync_temp, test_async_temp, test_sync_analysis, test_parallel_analysis

# %%
# Реальные средние температуры (примерные данные) для городов по сезонам
seasonal_temperatures = {
    "New York": {"winter": 0, "spring": 10, "summer": 25, "autumn": 15},
    "London": {"winter": 5, "spring": 11, "summer": 18, "autumn": 12},
    "Paris": {"winter": 4, "spring": 12, "summer": 20, "autumn": 13},
    "Tokyo": {"winter": 6, "spring": 15, "summer": 27, "autumn": 18},
    "Moscow": {"winter": -10, "spring": 5, "summer": 18, "autumn": 8},
    "Sydney": {"winter": 12, "spring": 18, "summer": 25, "autumn": 20},
    "Berlin": {"winter": 0, "spring": 10, "summer": 20, "autumn": 11},
    "Beijing": {"winter": -2, "spring": 13, "summer": 27, "autumn": 16},
    "Rio de Janeiro": {"winter": 20, "spring": 25, "summer": 30, "autumn": 25},
    "Dubai": {"winter": 20, "spring": 30, "summer": 40, "autumn": 30},
    "Los Angeles": {"winter": 15, "spring": 18, "summer": 25, "autumn": 20},
    "Singapore": {"winter": 27, "spring": 28, "summer": 28, "autumn": 27},
    "Mumbai": {"winter": 25, "spring": 30, "summer": 35, "autumn": 30},
    "Cairo": {"winter": 15, "spring": 25, "summer": 35, "autumn": 25},
    "Mexico City": {"winter": 12, "spring": 18, "summer": 20, "autumn": 15},
}

# Сопоставление месяцев с сезонами
month_to_season = {12: "winter", 1: "winter", 2: "winter",
                   3: "spring", 4: "spring", 5: "spring",
                   6: "summer", 7: "summer", 8: "summer",
                   9: "autumn", 10: "autumn", 11: "autumn"}

# Генерация данных о температуре
def generate_realistic_temperature_data(cities, num_years=10):
    dates = pd.date_range(start="2010-01-01", periods=365 * num_years, freq="D")
    data = []

    for city in cities:
        for date in dates:
            season = month_to_season[date.month]
            mean_temp = seasonal_temperatures[city][season]
            # Добавляем случайное отклонение
            temperature = np.random.normal(loc=mean_temp, scale=5)
            data.append({"city": city, "timestamp": date, "temperature": temperature})

    df = pd.DataFrame(data)
    df['season'] = df['timestamp'].dt.month.map(lambda x: month_to_season[x])
    return df

# Генерация данных
data = generate_realistic_temperature_data(list(seasonal_temperatures.keys()))
data.to_csv('temperature_data.csv', index=False)

# %% [markdown]
# ## Анализ исторических данных

# %% [markdown]
# ### Температуры для каждого сезона в каждом городе

# %% [markdown]
# Рассчитаем среднюю температуру и стандартное отклонение для каждого сезона в каждом городе

# %%
data.groupby(['city', 'season']).agg({'temperature': ('mean', 'std')})
# Out:
#                       temperature
#                              mean       std
# city           season
# Beijing        autumn   15.821265  4.971861
#                spring   13.133265  5.095347
#                summer   26.927165  5.100578
#                winter   -1.726743  5.125945
# Berlin         autumn   11.413522  4.964867
#                spring    9.781418  4.848280
#                summer   20.129910  4.942110
#                winter   -0.247984  4.901361
# Cairo          autumn   24.706609  5.109818
#                spring   24.845424  5.120604
#                summer   35.201019  4.968636
#                winter   14.839215  4.957106
# Dubai          autumn   30.017708  4.878068
#                spring   29.637859  4.907604
#                summer   39.964027  4.798981
#                winter   19.908876  5.018619
# London         autumn   11.771700  5.094544
#                spring   10.949947  4.815036
#                summer   18.175242  4.880203
#                winter    4.799531  5.039399
# Los Angeles    autumn   20.136928  5.092435
#                spring   17.831045  5.064521
#                summer   25.030278  4.857314
#                winter   15.019733  4.791543
# Mexico City    autumn   15.323339  4.994481
#                spring   17.758796  5.019460
#                summer   20.248207  5.293106
#                winter   11.849130  5.265686
# Moscow         autumn    7.845211  5.112778
#                spring    5.242447  4.982885
#                summer   17.846421  5.133337
#                winter   -9.955241  5.068607
# Mumbai         autumn   29.840180  4.887886
#                spring   30.079961  5.102112
#                summer   34.924435  5.014582
#                winter   25.014734  5.014904
# New York       autumn   15.195659  4.809125
#                spring   10.067800  4.779512
#                summer   24.997162  4.997121
#                winter    0.240244  4.855918
# Paris          autumn   13.162173  5.154244
#                spring   12.198375  4.959135
#                summer   19.955678  4.902371
#                winter    4.196652  5.143237
# Rio de Janeiro autumn   24.747007  4.975474
#                spring   25.120224  5.054899
#                summer   30.307513  5.008764
#                winter   19.790959  5.220738
# Singapore      autumn   27.015834  5.209366
#                spring   27.925003  4.844612
#                summer   28.270203  4.865309
#                winter   27.365064  4.957615
# Sydney         autumn   20.161858  4.986423
#                spring   17.863994  4.976218
#                summer   25.155679  5.143159
#                winter   11.937121  5.197082
# Tokyo          autumn   17.967897  4.913586
#                spring   14.957259  5.009331
#                summer   26.807097  5.089839
#                winter    5.817091  4.740167

# %% [markdown]
# С помощью groupby узнали необходимую информацию; для интереса и ~~попытки заработать дополнительных баллов~~ дополнительного анализа здесь и далее будем пытается смотреть на еще некоторые показатели / пилить что-то еще
#
# Например, в преддверии новогодних праздников выведем топ-3 города с самой теплой зимой (в среднем)

# %%
data[data['season'] == 'winter'].groupby(['city', 'season']).agg(
    {'temperature': 'mean'}).sort_values(by = 'temperature', ascending=False).head(3)
# Out:
#                   temperature
# city      season
# Singapore winter    27.365064
# Mumbai    winter    25.014734
# Dubai     winter    19.908876

# %% [markdown]
# Также глянем на самый стабильный город по температуре (наименьшее стандартное отклонение между сезонами)

# %%
grouped_data = data.groupby(['city', 'season']).agg({'temperature': 'mean'}).reset_index()

grouped_data.groupby('city').agg(
    {'temperature': 'std'}).sort_values(by = 'temperature').head(1)
# Out:
#            temperature
# city
# Singapore       0.5608

# %% [markdown]
# В Сингапуре практически не отличается погода в течение сезонов - логично! Он еще и во втором рейтинге подряд топ-1

# %% [markdown]
# ### Вычисление скользящего среднего

# %% [markdown]
# Узнаем скользящее среднее по городам

# %%
data['rolling_mean'] = data.groupby('city')['temperature'].rolling(window=30).mean().reset_index(level=0, drop=True)
data['rolling_std'] = data.groupby('city')['temperature'].rolling(window=7).std().reset_index(level=0, drop=True)

data[40:50] # для первых 30 временных отметок недостаточно данных для скользящего среднего
            # решил далее в функциях порог не снижать и просто их не использовать
# Out:
#         city  timestamp  temperature  season  rolling_mean  rolling_std
# 40  New York 2010-02-10    -2.320241  winter      0.302745     5.302739
# 41  New York 2010-02-11     2.540607  winter      0.430756     5.372809
# 42  New York 2010-02-12     5.911489  winter      0.539180     4.455389
# 43  New York 2010-02-13    -6.234762  winter      0.228495     5.073094
# 44  New York 2010-02-14     2.456590  winter      0.086863     4.741574
# 45  New York 2010-02-15    -5.453728  winter     -0.195654     4.961246
# 46  New York 2010-02-16    -1.750750  winter     -0.299367     4.493288
# 47  New York 2010-02-17     1.750607  winter     -0.343278     4.510977
# 48  New York 2010-02-18     0.226614  winter     -0.284645     4.366722
# 49  New York 2010-02-19    -5.469181  winter     -0.632763     3.669983

# %% [markdown]
# ### Поиск аномалий

# %%
data['is_anomaly'] = (data['temperature'] > data['rolling_mean'] + 2 *
                      data['rolling_std']) | (data['temperature'] < data['rolling_mean'] - 2 * data['rolling_std'])

data[data['is_anomaly'] == True]
# Out:
#               city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 59        New York 2010-03-01    14.041789  spring     -0.231454     5.951106
# 63        New York 2010-03-05    12.885706  spring      1.093626     5.831846
# 67        New York 2010-03-09    13.721536  spring      2.619479     4.548147
# 68        New York 2010-03-10    14.139883  spring      2.866047     4.990587
# 75        New York 2010-03-17    22.992054  spring      4.928291     6.433864
# ...            ...        ...          ...     ...           ...          ...
# 54650  Mexico City 2019-09-21     7.263223  autumn     17.415403     5.060853
# 54664  Mexico City 2019-10-05     5.173077  autumn     14.988051     3.660783
# 54676  Mexico City 2019-10-17     6.462397  autumn     14.530646     3.655637
# 54707  Mexico City 2019-11-17     0.294538  autumn     16.014036     7.158249
# 54729  Mexico City 2019-12-09     3.806497  winter     14.795110     5.315290
#
#        is_anomaly
# 59           True
# 63           True
# 67           True
# 68           True
# 75           True
# ...           ...
# 54650        True
# 54664        True
# 54676        True
# 54707        True
# 54729        True
#
# [4000 rows x 7 columns]

# %% [markdown]
# Посмотрим, в каком городе было больше неожиданных с точки зрения погоды дней

# %%
print(
    f"Город с наибольшим количеством аномальных дней: {data.groupby('city')['is_anomaly'].sum().idxmax()} "
    f"({data.groupby('city')['is_anomaly'].sum().max()} дня)\n"
    f"Город с наименьшим количеством аномальных дней: {data.groupby('city')['is_anomaly'].sum().idxmin()} "
    f"({data.groupby('city')['is_anomaly'].sum().min()} дня)"
)
# Out:
# Город с наибольшим количеством аномальных дней: Beijing (429 дня)
# Город с наименьшим количеством аномальных дней: Singapore (124 дня)

# %% [markdown]
# Сингапур снова топ-1!

# %% [markdown]
# ### Исследование распараллеливания анализа

# %% [markdown]
# Обернем весь код выше в функцию (скрипт), дополним его кодом про определение тренда. Функция буудет лежать (как и все остальные скрипты) в scripts.py

# %%
analysis('Moscow')
# Out:
# Текущий сезон для города Moscow: winter
#
# Минимальная температура в сезоне: -27.876830626043148
# Максимальная температура в сезоне: 5.757819626838792
# Средняя температура в сезоне:  -10.308275957852874
#
# Профиль текущего сезона города Moscow
#          city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 18245  Moscow 2019-12-25    -9.765358  winter     -9.291112     5.500929
# 18246  Moscow 2019-12-26    -7.142475  winter     -9.284995     4.738856
# 18247  Moscow 2019-12-27   -13.183317  winter     -9.317816     5.036299
# 18248  Moscow 2019-12-28   -12.224927  winter     -9.583863     5.182668
# 18249  Moscow 2019-12-29    -9.031708  winter     -9.708461     3.438407
#
#        is_anomaly                trend
# 18245       False  Положительный тренд
# 18246       False  Положительный тренд
# 18247       False  Положительный тренд
# 18248       False  Положительный тренд
# 18249       False  Положительный тренд

# %% [markdown]
# Немного корявый вывод: я изначально делал вывод с помощью display, а не print, но мультипроцессинг несовместим с юпитеровским display. Поэтому немного коряво вышло с print
#
# Попробуем теперь **асинхронный метод** и сравним работоспобность, вызвав функцию сразу для всех городов, сравним результаты по времени. Для этого напишем функции для тестирования, внесем их в utils.py. Для показательности выведем результат выполнения (время) при условии, что мы запустим сразу по всем городам

# %%
print("Тест синхронного анализа:")
test_sync_analysis()

print("\nТест параллельного анализа:")
test_parallel_analysis()
# Out:
# Тест синхронного анализа:
# Текущий сезон для города New York: winter
#
# Минимальная температура в сезоне: -14.17410627969581
# Максимальная температура в сезоне: 15.461155579740533
# Средняя температура в сезоне:  0.189212244512664
#
# Профиль текущего сезона города New York
#           city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 3645  New York 2019-12-25     9.614827  winter      0.108812     5.535941
# 3646  New York 2019-12-26    10.071146  winter      0.659973     6.124706
# 3647  New York 2019-12-27     0.164934  winter      0.549329     4.978215
# 3648  New York 2019-12-28     1.595547  winter      0.392490     4.532006
# 3649  New York 2019-12-29     2.356468  winter      0.409757     3.910796
#
#       is_anomaly                trend
# 3645       False  Положительный тренд
# 3646       False  Положительный тренд
# 3647       False  Положительный тренд
# 3648       False  Положительный тренд
# 3649       False  Положительный тренд
# Текущий сезон для города London: winter
#
# Минимальная температура в сезоне: -10.654948681400976
# Максимальная температура в сезоне: 21.75137768822716
# Средняя температура в сезоне:  4.589122193714502
#
# Профиль текущего сезона города London
#         city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 7295  London 2019-12-25     7.455872  winter      4.769661     4.410990
# 7296  London 2019-12-26    -1.712817  winter      4.432999     4.978497
# 7297  London 2019-12-27    10.754009  winter      4.952439     4.368143
# 7298  London 2019-12-28     6.118630  winter      4.875010     4.227069
# 7299  London 2019-12-29     3.920159  winter      4.854918     3.871091
#
#       is_anomaly                trend
# 7295       False  Положительный тренд
# 7296       False  Положительный тренд
# 7297       False  Положительный тренд
# 7298       False  Положительный тренд
# 7299       False  Положительный тренд
# Текущий сезон для города Paris: winter
#
# Минимальная температура в сезоне: -14.32607882902887
# Максимальная температура в сезоне: 19.012453106866793
# Средняя температура в сезоне:  3.9267091798432174
#
# Профиль текущего сезона города Paris
#         city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 10945  Paris 2019-12-25    -0.087619  winter      3.993465     7.112600
# 10946  Paris 2019-12-26     9.824162  winter      3.892382     7.309449
# 10947  Paris 2019-12-27     1.536761  winter      4.003446     7.005125
# 10948  Paris 2019-12-28     6.009527  winter      3.942572     6.952127
# 10949  Paris 2019-12-29     2.800682  winter      4.027521     4.384219
#
#        is_anomaly                trend
# 10945       False  Отрицательный тренд
# 10946       False  Отрицательный тренд
# 10947       False  Отрицательный тренд
# 10948       False  Отрицательный тренд
# 10949       False  Отрицательный тренд
# Текущий сезон для города Tokyo: winter
#
# Минимальная температура в сезоне: -7.31451241181435
# Максимальная температура в сезоне: 22.45734649334668
# Средняя температура в сезоне:  6.060391563679604
#
# Профиль текущего сезона города Tokyo
#         city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 14595  Tokyo 2019-12-25     8.318106  winter      4.172261     3.757491
# 14596  Tokyo 2019-12-26    11.253170  winter      4.501261     4.947513
# 14597  Tokyo 2019-12-27     2.998047  winter      4.334445     4.844371
# 14598  Tokyo 2019-12-28    18.682920  winter      4.880910     7.518930
# 14599  Tokyo 2019-12-29    -0.033622  winter      4.914166     7.685330
#
#        is_anomaly                trend
# 14595       False  Положительный тренд
# 14596       False  Положительный тренд
# 14597       False  Положительный тренд
# 14598       False  Положительный тренд
# 14599       False  Положительный тренд
# Текущий сезон для города Moscow: winter
#
# Минимальная температура в сезоне: -27.876830626043148
# Максимальная температура в сезоне: 5.757819626838792
# Средняя температура в сезоне:  -10.308275957852874
#
# Профиль текущего сезона города Moscow
#          city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 18245  Moscow 2019-12-25    -9.765358  winter     -9.291112     5.500929
# 18246  Moscow 2019-12-26    -7.142475  winter     -9.284995     4.738856
# 18247  Moscow 2019-12-27   -13.183317  winter     -9.317816     5.036299
# 18248  Moscow 2019-12-28   -12.224927  winter     -9.583863     5.182668
# 18249  Moscow 2019-12-29    -9.031708  winter     -9.708461     3.438407
#
#        is_anomaly                trend
# 18245       False  Положительный тренд
# 18246       False  Положительный тренд
# 18247       False  Положительный тренд
# 18248       False  Положительный тренд
# 18249       False  Положительный тренд
# Текущий сезон для города Sydney: winter
#
# Минимальная температура в сезоне: -4.739949578627318
# Максимальная температура в сезоне: 27.586982550596577
# Средняя температура в сезоне:  11.89901118909004
#
# Профиль текущего сезона города Sydney
#          city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 21895  Sydney 2019-12-25    14.098263  winter     12.586639     3.413179
# 21896  Sydney 2019-12-26    -0.335839  winter     12.423864     6.130904
# 21897  Sydney 2019-12-27    26.075000  winter     12.624135     8.188228
# 21898  Sydney 2019-12-28     9.619256  winter     12.827031     8.036643
# 21899  Sydney 2019-12-29    13.918000  winter     12.888732     8.029657
#
#        is_anomaly                trend
# 21895       False  Отрицательный тренд
# 21896        True  Отрицательный тренд
# 21897       False  Отрицательный тренд
# 21898       False  Отрицательный тренд
# 21899       False  Отрицательный тренд
# Текущий сезон для города Berlin: winter
#
# Минимальная температура в сезоне: -14.880561456038796
# Максимальная температура в сезоне: 17.426869456275462
# Средняя температура в сезоне:  -0.1354753093638887
#
# Профиль текущего сезона города Berlin
#          city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 25545  Berlin 2019-12-25    -8.007434  winter     -0.309608     6.176452
# 25546  Berlin 2019-12-26     1.195205  winter     -0.253012     5.432171
# 25547  Berlin 2019-12-27    -3.611098  winter     -0.254278     5.476789
# 25548  Berlin 2019-12-28     1.190978  winter      0.031764     4.057968
# 25549  Berlin 2019-12-29     6.622710  winter      0.281381     5.231737
#
#        is_anomaly                trend
# 25545       False  Отрицательный тренд
# 25546       False  Отрицательный тренд
# 25547       False  Отрицательный тренд
# 25548       False  Отрицательный тренд
# 25549       False  Отрицательный тренд
# Текущий сезон для города Beijing: winter
#
# Минимальная температура в сезоне: -19.50915316321733
# Максимальная температура в сезоне: 15.479976061731504
# Средняя температура в сезоне:  -2.1309661445320947
#
# Профиль текущего сезона города Beijing
#           city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 29195  Beijing 2019-12-25    -5.591865  winter     -2.340003     6.827788
# 29196  Beijing 2019-12-26    -0.964203  winter     -1.907534     5.173268
# 29197  Beijing 2019-12-27    -5.718558  winter     -2.135354     5.190105
# 29198  Beijing 2019-12-28     4.608373  winter     -2.084428     6.003680
# 29199  Beijing 2019-12-29    -6.007511  winter     -1.986900     4.832787
#
#        is_anomaly                trend
# 29195       False  Положительный тренд
# 29196       False  Положительный тренд
# 29197       False  Положительный тренд
# 29198       False  Положительный тренд
# 29199       False  Положительный тренд
# Текущий сезон для города Rio de Janeiro: winter
#
# Минимальная температура в сезоне: 4.978064576389086
# Максимальная температура в сезоне: 34.61581574036079
# Средняя температура в сезоне:  20.006195273011134
#
# Профиль текущего сезона города Rio de Janeiro
#                  city  timestamp  temperature  season  rolling_mean  \
# 32845  Rio de Janeiro 2019-12-25    23.562109  winter     20.078121
# 32846  Rio de Janeiro 2019-12-26    22.348256  winter     19.719347
# 32847  Rio de Janeiro 2019-12-27    17.173134  winter     19.697901
# 32848  Rio de Janeiro 2019-12-28    15.508285  winter     19.537243
# 32849  Rio de Janeiro 2019-12-29    27.035088  winter     19.721467
#
#        rolling_std  is_anomaly                trend
# 32845     3.490731       False  Положительный тренд
# 32846     3.712930       False  Положительный тренд
# 32847     3.594747       False  Положительный тренд
# 32848     3.796544       False  Положительный тренд
# 32849     4.633303       False  Положительный тренд
# Текущий сезон для города Dubai: winter
#
# Минимальная температура в сезоне: 4.909934059005532
# Максимальная температура в сезоне: 40.149655201179975
# Средняя температура в сезоне:  20.030206212159975
#
# Профиль текущего сезона города Dubai
#         city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 36495  Dubai 2019-12-25    24.744462  winter     18.772175     6.254629
# 36496  Dubai 2019-12-26    20.385387  winter     18.967171     6.440049
# 36497  Dubai 2019-12-27    14.816663  winter     18.616267     6.310076
# 36498  Dubai 2019-12-28    21.557906  winter     18.457827     6.350053
# 36499  Dubai 2019-12-29    18.067679  winter     18.549047     6.353754
#
#        is_anomaly                trend
# 36495       False  Отрицательный тренд
# 36496       False  Отрицательный тренд
# 36497       False  Отрицательный тренд
# 36498       False  Отрицательный тренд
# 36499       False  Отрицательный тренд
# Текущий сезон для города Los Angeles: winter
#
# Минимальная температура в сезоне: 1.998264671008072
# Максимальная температура в сезоне: 30.056699514801434
# Средняя температура в сезоне:  15.313916817299798
#
# Профиль текущего сезона города Los Angeles
#               city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 40145  Los Angeles 2019-12-25    18.529659  winter     15.582371     2.094909
# 40146  Los Angeles 2019-12-26    16.597299  winter     15.667824     1.695803
# 40147  Los Angeles 2019-12-27    12.118827  winter     15.612968     2.040694
# 40148  Los Angeles 2019-12-28    20.296506  winter     15.751759     2.645547
# 40149  Los Angeles 2019-12-29    18.295238  winter     15.986539     2.567186
#
#        is_anomaly                trend
# 40145       False  Положительный тренд
# 40146       False  Положительный тренд
# 40147       False  Положительный тренд
# 40148       False  Положительный тренд
# 40149       False  Положительный тренд
# Текущий сезон для города Singapore: winter
#
# Минимальная температура в сезоне: 11.958137157743137
# Максимальная температура в сезоне: 43.634349014485814
# Средняя температура в сезоне:  27.134571953606777
#
# Профиль текущего сезона города Singapore
#             city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 43795  Singapore 2019-12-25    29.409448  winter     26.393464     5.264943
# 43796  Singapore 2019-12-26    24.722446  winter     26.664600     5.214741
# 43797  Singapore 2019-12-27    37.062179  winter     27.033770     7.018657
# 43798  Singapore 2019-12-28    22.563638  winter     26.928288     7.135456
# 43799  Singapore 2019-12-29    29.825246  winter     26.690271     7.208185
#
#        is_anomaly                trend
# 43795       False  Положительный тренд
# 43796       False  Положительный тренд
# 43797       False  Положительный тренд
# 43798       False  Положительный тренд
# 43799       False  Положительный тренд
# Текущий сезон для города Mumbai: winter
#
# Минимальная температура в сезоне: 8.41641062435337
# Максимальная температура в сезоне: 41.70138452344124
# Средняя температура в сезоне:  25.157831153526317
#
# Профиль текущего сезона города Mumbai
#          city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 47445  Mumbai 2019-12-25    20.868874  winter     23.756834     4.345044
# 47446  Mumbai 2019-12-26    23.577758  winter     23.539237     4.363320
# 47447  Mumbai 2019-12-27    30.585434  winter     23.851993     4.180306
# 47448  Mumbai 2019-12-28    32.870476  winter     24.424731     4.803645
# 47449  Mumbai 2019-12-29    23.157111  winter     24.382836     4.975143
#
#        is_anomaly                trend
# 47445       False  Положительный тренд
# 47446       False  Положительный тренд
# 47447       False  Положительный тренд
# 47448       False  Положительный тренд
# 47449       False  Положительный тренд
# Текущий сезон для города Cairo: winter
#
# Минимальная температура в сезоне: 0.9459397637386102
# Максимальная температура в сезоне: 29.714897431665168
# Средняя температура в сезоне:  15.044363765874731
#
# Профиль текущего сезона города Cairo
#         city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 51095  Cairo 2019-12-25    10.119251  winter     15.578062     6.032144
# 51096  Cairo 2019-12-26    17.915131  winter     15.594706     6.026493
# 51097  Cairo 2019-12-27    13.160820  winter     15.565992     5.845172
# 51098  Cairo 2019-12-28    13.573158  winter     15.440194     5.414719
# 51099  Cairo 2019-12-29     5.132013  winter     15.099397     5.965414
#
#        is_anomaly                trend
# 51095       False  Положительный тренд
# 51096       False  Положительный тренд
# 51097       False  Положительный тренд
# 51098       False  Положительный тренд
# 51099       False  Положительный тренд
# Текущий сезон для города Mexico City: winter
#
# Минимальная температура в сезоне: -5.320835424557
# Максимальная температура в сезоне: 30.43282384942731
# Средняя температура в сезоне:  11.958236150947469
#
# Профиль текущего сезона города Mexico City
#               city  timestamp  temperature  season  rolling_mean  rolling_std  \
# 54745  Mexico City 2019-12-25    14.114715  winter     12.198466     5.432038
# 54746  Mexico City 2019-12-26    21.743527  winter     12.467423     6.420455
# 54747  Mexico City 2019-12-27     4.167349  winter     12.298595     6.420331
# 54748  Mexico City 2019-12-28    14.499265  winter     12.612777     6.524949
# 54749  Mexico City 2019-12-29    16.483856  winter     12.697217     5.565660
#
#        is_anomaly                trend
# 54745       False  Отрицательный тренд
# 54746       False  Отрицательный тренд
# 54747       False  Отрицательный тренд
# 54748       False  Отрицательный тренд
# 54749       False  Отрицательный тренд
# Среднее время выполнения синхронного анализа на один город: 0.01 секунд
# Общее время выполнения синхронного анализа: 0.15 секунд
#
# Тест параллельного анализа:
# Текущий сезон для города Berlin: winter
#
# Минимальная температура в сезоне: -14.537451612181984
# Максимальная температура в сезоне: 15.013420402114448
# Средняя температура в сезоне:  -0.24798378607717242
#
# Профиль текущего сезона города Berlin
#          city  timestamp  ...  is_anomaly                trend
# 25545  Berlin 2019-12-25  ...       False  Отрицательный тренд
# 25546  Berlin 2019-12-26  ...       False  Отрицательный тренд
# 25547  Berlin 2019-12-27  ...       False  Отрицательный тренд
# 25548  Berlin 2019-12-28  ...       False  Отрицательный тренд
# 25549  Berlin 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города London: winter
#
# Минимальная температура в сезоне: -10.313424737209155
# Максимальная температура в сезоне: 23.996517998154665
# Средняя температура в сезоне:  4.799530948161799
#
# Профиль текущего сезона города London
#         city  timestamp  ...  is_anomaly                trend
# 7295  London 2019-12-25  ...       False  Положительный тренд
# 7296  London 2019-12-26  ...       False  Положительный тренд
# 7297  London 2019-12-27  ...       False  Положительный тренд
# 7298  London 2019-12-28  ...       False  Положительный тренд
# 7299  London 2019-12-29  ...       False  Положительный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Mumbai: winter
#
# Минимальная температура в сезоне: 10.60611739237592
# Максимальная температура в сезоне: 45.1812487014128
# Средняя температура в сезоне:  25.014734252793648
#
# Профиль текущего сезона города Mumbai
#          city  timestamp  ...  is_anomaly                trend
# 47445  Mumbai 2019-12-25  ...       False  Отрицательный тренд
# 47446  Mumbai 2019-12-26  ...       False  Отрицательный тренд
# 47447  Mumbai 2019-12-27  ...       False  Отрицательный тренд
# 47448  Mumbai 2019-12-28  ...       False  Отрицательный тренд
# 47449  Mumbai 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города New York: winter
#
# Минимальная температура в сезоне: -14.19739030199229
# Максимальная температура в сезоне: 16.5467974004353
# Средняя температура в сезоне:  0.24024359457132757
#
# Профиль текущего сезона города New York
#           city  timestamp  ...  is_anomaly                trend
# 3645  New York 2019-12-25  ...       False  Положительный тренд
# 3646  New York 2019-12-26  ...       False  Положительный тренд
# 3647  New York 2019-12-27  ...       False  Положительный тренд
# 3648  New York 2019-12-28  ...       False  Положительный тренд
# 3649  New York 2019-12-29  ...       False  Положительный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Rio de Janeiro: winter
#
# Минимальная температура в сезоне: 2.8351062821257544
# Максимальная температура в сезоне: 38.7322159605528
# Средняя температура в сезоне:  19.790959295639077
#
# Профиль текущего сезона города Rio de Janeiro
#                  city  timestamp  ...  is_anomaly                trend
# 32845  Rio de Janeiro 2019-12-25  ...       False  Отрицательный тренд
# 32846  Rio de Janeiro 2019-12-26  ...       False  Отрицательный тренд
# 32847  Rio de Janeiro 2019-12-27  ...       False  Отрицательный тренд
# 32848  Rio de Janeiro 2019-12-28  ...       False  Отрицательный тренд
# 32849  Rio de Janeiro 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Dubai: winter
#
# Минимальная температура в сезоне: 4.634607936049562
# Максимальная температура в сезоне: 35.70198427442763
# Средняя температура в сезоне:  19.908876356656176
#
# Профиль текущего сезона города Dubai
#         city  timestamp  ...  is_anomaly                trend
# 36495  Dubai 2019-12-25  ...       False  Отрицательный тренд
# 36496  Dubai 2019-12-26  ...       False  Отрицательный тренд
# 36497  Dubai 2019-12-27  ...       False  Отрицательный тренд
# 36498  Dubai 2019-12-28  ...       False  Отрицательный тренд
# 36499  Dubai 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Singapore: winter
#
# Минимальная температура в сезоне: 11.35148790444996
# Максимальная температура в сезоне: 45.50024285089218
# Средняя температура в сезоне:  27.36506422538533
#
# Профиль текущего сезона города Singapore
#             city  timestamp  ...  is_anomaly                trend
# 43795  Singapore 2019-12-25  ...       False  Отрицательный тренд
# 43796  Singapore 2019-12-26  ...       False  Отрицательный тренд
# 43797  Singapore 2019-12-27  ...       False  ��трицательный тренд
# 43798  Singapore 2019-12-28  ...       False  Отрицательный тренд
# 43799  Singapore 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Mexico City: winter
#
# Минимальная температура в сезоне: -2.8860327365179423
# Максимальная температура в сезоне: 30.118271734903377
# Средняя температура в сезоне:  11.849129626924634
#
# Профиль текущего сезона города Mexico City
#               city  timestamp  ...  is_anomaly                trend
# 54745  Mexico City 2019-12-25  ...       False  Положительный тренд
# 54746  Mexico City 2019-12-26  ...       False  Положительный тренд
# 54747  Mexico City 2019-12-27  ...       False  Положительный тренд
# 54748  Mexico City 2019-12-28  ...       False  Положител��ный тренд
# 54749  Mexico City 2019-12-29  ...       False  Положительный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Moscow: winter
#
# Минимальная температура в сезоне: -27.432893790839938
# Максимальная температура в сезоне: 8.164977360699563
# Средняя температура в сезоне:  -9.955240662689716
#
# Профиль текущего сезона города Moscow
#          city  timestamp  ...  is_anomaly                trend
# 18245  Moscow 2019-12-25  ...       False  Отрицательный тренд
# 18246  Moscow 2019-12-26  ...       False  Отрицательный тренд
# 18247  Moscow 2019-12-27  ...       False  Отрицательный тренд
# 18248  Moscow 2019-12-28  ...       False  Отрицательный тренд
# 18249  Moscow 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Paris: winter
#
# Минимальная температура в сезоне: -12.113758212339537
# Максимальная температура в сезоне: 20.410938020180165
# Средняя температура в сезоне:  4.196651650785659
#
# Профиль текущего сезона города Paris
#         city  timestamp  ...  is_anomaly                trend
# 10945  Paris 2019-12-25  ...       False  Положительный тренд
# 10946  Paris 2019-12-26  ...       False  Положительный тренд
# 10947  Paris 2019-12-27  ...       False  Положительный тренд
# 10948  Paris 2019-12-28  ...       False  Положительный тренд
# 10949  Paris 2019-12-29  ...       False  Положительный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Los Angeles: winter
#
# Минимальная температура в сезоне: -2.9991010908189253
# Максим��льная температура в сезоне: 27.954708526079212
# Средняя температура в сезоне:  15.019733476974459
#
# Профиль текущего сезона города Los Angeles
#               city  timestamp  ...  is_anomaly                trend
# 40145  Los Angeles 2019-12-25  ...       False  Отрицательный тренд
# 40146  Los Angeles 2019-12-26  ...       False  Отрицательный тренд
# 40147  Los Angeles 2019-12-27  ...       False  Отрицательный тренд
# 40148  Los Angeles 2019-12-28  ...       False  Отрицательный тренд
# 40149  Los Angeles 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Cairo: winter
#
# Минимальная температура в сезоне: -1.119570342204601
# Максимальная температура в сезоне: 28.0330628915611
# Средняя температура в сезоне:  14.839214522028083
#
# Профиль текущего сезона города Cairo
#         city  timestamp  ...  is_anomaly                trend
# 51095  Cairo 2019-12-25  ...       False  Отрицательный тренд
# 51096  Cairo 2019-12-26  ...       False  Отрицательный тренд
# 51097  Cairo 2019-12-27  ...       False  Отрицательный тренд
# 51098  Cairo 2019-12-28  ...       False  Отрицательный тренд
# 51099  Cairo 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Sydney: winter
#
# Минимальная температура в сезоне: -3.4145980903872704
# Максимальная температура в сезоне: 30.08918555432303
# Средняя температура в сезоне:  11.937120669783138
#
# Профиль текущего сезона города Sydney
#          city  timestamp  ...  is_anomaly                trend
# 21895  Sydney 2019-12-25  ...       False  Положительный тренд
# 21896  Sydney 2019-12-26  ...        True  Положительный тренд
# 21897  Sydney 2019-12-27  ...       False  Положительный тренд
# 21898  Sydney 2019-12-28  ...       False  Положительный тренд
# 21899  Sydney 2019-12-29  ...       False  Положительный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Tokyo: winter
#
# Минимальная температура в сезоне: -10.417702212820046
# Максимальная температура в сезоне: 23.529358755287745
# Средняя температура в сезоне:  5.817090861075463
#
# Профиль текущего сезона города Tokyo
#         city  timestamp  ...  is_anomaly                trend
# 14595  Tokyo 2019-12-25  ...       False  Отрицательный тренд
# 14596  Tokyo 2019-12-26  ...       False  Отрицательный тренд
# 14597  Tokyo 2019-12-27  ...       False  Отрицательный тренд
# 14598  Tokyo 2019-12-28  ...       False  Отрицательный тренд
# 14599  Tokyo 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Текущий сезон для города Beijing: winter
#
# Минимальная температура в сезоне: -17.356825274101222
# Максимальная температура в сезоне: 14.758602396290335
# Средняя температура в сезоне:  -1.726742777706028
#
# Профиль текущего сезона города Beijing
#           city  timestamp  ...  is_anomaly                trend
# 29195  Beijing 2019-12-25  ...       False  Отрицательный тренд
# 29196  Beijing 2019-12-26  ...       False  Отрицательный тренд
# 29197  Beijing 2019-12-27  ...       False  Отрицательный тренд
# 29198  Beijing 2019-12-28  ...       False  Отрицательный тренд
# 29199  Beijing 2019-12-29  ...       False  Отрицательный тренд
#
# [5 rows x 8 columns]
# Среднее время выполнения параллельного анализа на один город: 0.14 секунд
# Общее время выполнения параллельного анализа: 2.17 секунд

# %% [markdown]
# Результаты стали хуже :(
#
# 1. Среднее время выполнения синхронного анализа на один город: 0.01 секунд
# Общее время выполнения синхронного анализа: 0.15 секунд
#
# 2. Среднее время выполнения параллельного анализа на один город: 0.15 секунд
# Общее время выполнения параллельного анализа: 2.18 секунд
#
# У нас обработка одного города выполняется быстро (за 0.01 секунды), время на создание и управление процессами перевешивает пользу от их использования

# %% [markdown]
# ## Монтиоринг текущей температуры

# %% [markdown]
# ### Анализ текущей температуры

# %% [markdown]
# Напишем функцию, которая будет получать текущую температуру для выбранного города, а также определять, является ли текщуая температура нормальной

# %%
current_temp('Beijing')
# Out:
# Текущая температура: 270.09 K / -3.06 °C
# 2.912580021298937
# 0.5997206059044432
# Текущая погода ниже нормы для текущего сезона

# %% [markdown]
# Протестируем решение на данных в задании городах

# %%
cities = ["Berlin", "Cairo", "Dubai", "Beijing", "Moscow"]

print("Проверяем текущую погоду для 5 городов:")
for city in cities:
    print("_" * 50)
    print(f"Город: {city}")
    current_temp(city)
# Out:
# Проверяем текущую погоду для 5 городов:
# __________________________________________________
# Город: Berlin
# Текущая температура: 278.99 K / 5.84 °C
# 2.740052074393009
# 0.9872408764284175
# Текущая погода выше нормы для текущего сезона
# __________________________________________________
# Город: Cairo
# Текущая температура: 294.57 K / 21.42 °C
# 17.492500398384617
# 0.7902977134136651
# Текущая погода выше нормы для текущего сезона
# __________________________________________________
# Город: Dubai
# Текущая температура: 296.11 K / 22.96 °C
# 22.66028803316494
# 0.6564470372968394
# Погода нормальна для текущего сезона
# __________________________________________________
# Город: Beijing
# Текущая температура: 270.09 K / -3.06 °C
# 2.912580021298937
# 0.5997206059044432
# Текущая погода ниже нормы для текущего сезона
# __________________________________________________
# Город: Moscow
# Текущая температура: 271.33 K / -1.82 °C
# -5.55730240663585
# 0.913188162327086
# Текущая погода выше нормы для текущего сезона

# %% [markdown]
# Получилось так, что небольшие аномалии обнаружены в Пекине (как и, видимо, предполагалось заданием) и в Дубае (связываю это с тем, что выполняю эту ячейку под ночь - температура сейчас будет ниже). Нет аномалии в Москве, но будто бы в эти дни в Москве аномально тепло для декабря (предполагаемая аномалия в данных плюс реально аномалия дает отсутствие аномалии так сказать)

# %% [markdown]
# ### Асинхронный метод, сравнение

# %% [markdown]
# Попробуем теперь асинхронный метод и сравним работоспобность, вызвав функцию сразу для всех городов, сравним результаты по времени. Для этого напишем функции для тестирования, внесем их в utils.py. Для показательности выведем результат выполнения (время) при условии, что мы запустим сразу по всем городам

# %%
print("Тест синхронной функции:")
test_sync_temp()

print("\nТест асинхронной функции:")
await test_async_temp()
# Out:
# Тест синхронной функции:
# Текущая температура: 264.51 K / -8.64 °C
# 3.9604946379313795
# 0.8114271458875297
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 279.36 K / 6.21 °C
# 6.681051479970328
# 0.8355664391943162
# Погода нормальна для текущего сезона
# Текущая температура: 280.49 K / 7.34 °C
# 6.688862602713229
# 0.78202448371885
# Погода нормальна для текущего сезона
# Текущая температура: 277.08 K / 3.93 °C
# 9.120234813557724
# 0.8488253650739982
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 271.33 K / -1.82 °C
# -5.55730240663585
# 0.913188162327086
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 296.58 K / 23.43 °C
# 13.871225633971573
# 0.5098734886868355
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 278.99 K / 5.84 °C
# 2.740052074393009
# 0.9872408764284175
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 270.09 K / -3.06 °C
# 2.912580021298937
# 0.5997206059044432
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 299.76 K / 26.61 °C
# 21.51688146462232
# 0.8684307038955728
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 296.11 K / 22.96 °C
# 22.66028803316494
# 0.6564470372968394
# Погода нормальна для текущего сезона
# Текущая температура: 284.98 K / 11.83 °C
# 16.600371457145854
# 0.8152706403006186
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 300.9 K / 27.75 °C
# 26.872622524417487
# 1.1250637274853141
# Погода нормальна для текущего сезона
# Текущая температура: 299.14 K / 25.99 °C
# 26.674606869613108
# 0.5578567406863435
# Погода нормальна для текущего сезона
# Текущая температура: 294.57 K / 21.42 °C
# 17.492500398384617
# 0.7902977134136651
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 284.79 K / 11.64 °C
# 12.563529621590778
# 1.0784789968214268
# Погода нормальна для текущего сезона
# Среднее время выполнения синхронно на один город: 0.27 секунд
# Общее время выполнения синхронно: 4.09 секунд
#
# Тест асинхронной функции:
# Текущая температура: 280.49 K / 7.34 °C
# 6.688862602713229
# 0.78202448371885
# Погода нормальна для текущего сезона
# Текущая температура: 279.36 K / 6.21 °C
# 6.681051479970328
# 0.8355664391943162
# Погода нормальна для текущего сезона
# Текущая температура: 277.08 K / 3.93 °C
# 9.120234813557724
# 0.8488253650739982
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 299.14 K / 25.99 °C
# 26.674606869613108
# 0.5578567406863435
# Погода нормальна для текущего сезона
# Текущая температура: 264.56 K / -8.59 °C
# 3.9604946379313795
# 0.8114271458875297
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 300.9 K / 27.75 °C
# 26.872622524417487
# 1.1250637274853141
# Погода нормальна для текущего сезона
# Текущая температура: 285.14 K / 11.99 °C
# 16.600371457145854
# 0.8152706403006186
# Текущая погода ниже нормы для текущего сезона
# Текущая температура: 278.99 K / 5.84 °C
# 2.740052074393009
# 0.9872408764284175
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 299.76 K / 26.61 °C
# 21.51688146462232
# 0.8684307038955728
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 294.57 K / 21.42 °C
# 17.492500398384617
# 0.7902977134136651
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 284.79 K / 11.64 °C
# 12.563529621590778
# 1.0784789968214268
# Погода нормальна для текущего сезона
# Текущая температура: 296.58 K / 23.43 °C
# 13.871225633971573
# 0.5098734886868355
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 271.33 K / -1.82 °C
# -5.55730240663585
# 0.913188162327086
# Текущая погода выше нормы для текущего сезона
# Текущая температура: 296.11 K / 22.96 °C
# 22.66028803316494
# 0.6564470372968394
# Погода нормальна для текущего сезона
# Текущая температура: 270.09 K / -3.06 °C
# 2.912580021298937
# 0.5997206059044432
# Текущая погода ниже нормы для текущего сезона
# Среднее время выполнения асинхронно на один город: 0.05 секунд
# Общее время выполнения асинхронно: 0.75 секунд

# %% [markdown]
# Стало сильно лучше!
#
# 1. Среднее время выполнения синхронно на один город: 0.23 секунд
#
#     Общее время выполнения синхронно: 3.41 секунд
#
# 2. Среднее время выполнения асинхронно на один город: 0.03 секунд
#
#     Общее время выполнения асинхронно: 0.48 секунд

# %%
# !python3 dashboard.py
# Out:
# 2024-12-22 16:04:39.486 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run dashboard.py [ARGUMENTS]
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.567 Session state does not function when running a script without `streamlit run`
# 2024-12-22 16:04:39.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-22 16:04:39.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Traceback (most recent call last):
#   File "/Users/ismailismailov/Downloads/dashboard.py", line 27, in <module>
#     cities = data['city'].unique()
# NameError: name 'data' is not defined
